# %%
## librerias
from biopandas.pdb import PandasPdb
from Bio.PDB import PDBParser, Atom
import statistics

# %%
## load pdb
ppdb = PandasPdb()
ppdb.read_pdb('/home/ahr/Desktop/2q09.pdb')
ppdb.df.keys()
# Out:
# dict_keys(['ATOM', 'HETATM', 'ANISOU', 'OTHERS'])

# %%
# get information data of atoms
ppdb.df['ATOM'].head()
# Out:
#   record_name  atom_number blank_1 atom_name alt_loc residue_name blank_2  \
# 0        ATOM            1                 N                  ASN
# 1        ATOM            2                CA                  ASN
# 2        ATOM            3                 C                  ASN
# 3        ATOM            4                 O                  ASN
# 4        ATOM            5                CB                  ASN
#
#   chain_id  residue_number insertion  ... x_coord  y_coord  z_coord  \
# 0        A               4            ...  30.770    6.709   25.206
# 1        A               4            ...  29.405    6.309   25.670
# 2        A               4            ...  28.368    7.396   25.376
# 3        A               4            ...  27.912    8.102   26.272
# 4        A               4            ...  29.440    5.993   27.173
#
#    occupancy  b_factor  blank_4 segment_id element_symbol charge  line_idx
# 0        1.0     58.06                                  N    NaN       513
# ...

# %%
# get information data of atoms
ppdb.df['ATOM'].head()
# Out:
#   record_name  atom_number blank_1 atom_name alt_loc residue_name blank_2  \
# 0        ATOM            1                 N                  ASN
# 1        ATOM            2                CA                  ASN
# 2        ATOM            3                 C                  ASN
# 3        ATOM            4                 O                  ASN
# 4        ATOM            5                CB                  ASN
#
#   chain_id  residue_number insertion  ... x_coord  y_coord  z_coord  \
# 0        A               4            ...  30.770    6.709   25.206
# 1        A               4            ...  29.405    6.309   25.670
# 2        A               4            ...  28.368    7.396   25.376
# 3        A               4            ...  27.912    8.102   26.272
# 4        A               4            ...  29.440    5.993   27.173
#
#    occupancy  b_factor  blank_4 segment_id element_symbol charge  line_idx
# 0        1.0     58.06                                  N    NaN       513
# ...

# %%
##select dataframe of interest
#ppdb.df['ATOM'].loc[:, ['atom_name' , 'chain_id']].head()

# %%
#save the dataframe of interest in a new variable
b_factor = ppdb.df['ATOM'].loc[:, 'x_coord'].head()
##plot histogram
b_factor.hist()
# Out:
# <AxesSubplot:>

# %%
#make a list of the dataframe
b_factor.to_list()
#get average
statistics.mean(b_factor)
# Out:
# 57.664
